# %%
import os
import json
from tqdm import tqdm
from collections import defaultdict

import pickle

# %%
raw_data_dir="/home/ec2-user/quic-efs/user/bowenjin/llm-graph-plugin/data/raw_data/biology"
save_dir="/home/ec2-user/quic-efs/user/bowenjin/llm-graph-plugin/data/processed_data/biology"

# %%
## read raw data files

def read_json(file):
    with open(file) as f:
        data = json.load(f)
    return data

raw_data = json.load(open(os.path.join(raw_data_dir, 'hetionet-v1.0.json')))

# %%
raw_data.keys()
# Out:
# dict_keys(['metanode_kinds', 'metaedge_tuples', 'kind_to_abbrev', 'nodes', 'edges'])

# %%
raw_data['metanode_kinds']
# Out:
# ['Anatomy',
#  'Biological Process',
#  'Cellular Component',
#  'Compound',
#  'Disease',
#  'Gene',
#  'Molecular Function',
#  'Pathway',
#  'Pharmacologic Class',
#  'Side Effect',
#  'Symptom']

# %%
raw_data['nodes']
# Out:
# [{'kind': 'Molecular Function',
#   'identifier': 'GO:0031753',
#   'name': 'endothelial differentiation G-protein coupled receptor binding',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0031753'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0023448',
#   'name': 'Lymphocytic leukaemia',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0023448'}},
#  {'kind': 'Gene',
#   'identifier': 5345,
#   'name': 'SERPINF2',
#   'data': {'description': 'serpin peptidase inhibitor, clade F (alpha-2 antiplasmin, pigment epithelium derived factor), member 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/5345',
#    'chromosome': '17'}},
#  {'kind': 'Gene',
#   'identifier': 9409,
#   'name': 'PEX16',
#   'data': {'description': 'peroxisomal biogenesis factor 16',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/9409',
#    'chromosome': '11'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0032474',
#   'name': 'otolith morphogenesis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0032474'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010536',
#   'name': 'positive regulation of activation of Janus kinase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010536'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0575810',
#   'name': 'Hands weakness of',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0575810'}},
#  {'kind': 'Gene',
#   'identifier': 10848,
#   'name': 'PPP1R13L',
#   'data': {'description': 'protein phosphatase 1, regulatory subunit 13 like',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10848',
#    'chromosome': '19'}},
#  {'kind': 'Gene',
#   'identifier': 121129,
#   'name': 'OR2AP1',
#   'data': {'description': 'olfactory receptor, family 2, subfamily AP, member 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/121129',
#    'chromosome': '12'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010759',
#   'name': 'positive regulation of macrophage chemotaxis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010759'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0009100',
#   'name': 'glycoprotein metabolic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0009100'}},
#  {'kind': 'Gene',
#   'identifier': 432,
#   'name': 'ASGR1',
#   'data': {'description': 'asialoglycoprotein receptor 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/432',
#    'chromosome': '17'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0038183',
#   'name': 'bile acid signaling pathway',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0038183'}},
#  {'kind': 'Gene',
#   'identifier': 120526,
#   'name': 'DNAJC24',
#   'data': {'description': 'DnaJ (Hsp40) homolog, subfamily C, member 24',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/120526',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 100506164,
#   'name': 'HSFX1',
#   'data': {'description': 'heat shock transcription factor family, X linked 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/100506164',
#    'chromosome': 'X'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0060167',
#   'name': 'regulation of adenosine receptor signaling pathway',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0060167'}},
#  {'kind': 'Gene',
#   'identifier': 22938,
#   'name': 'SNW1',
#   'data': {'description': 'SNW domain containing 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/22938',
#    'chromosome': '14'}},
#  {'kind': 'Gene',
#   'identifier': 4656,
#   'name': 'MYOG',
#   'data': {'description': 'myogenin (myogenic factor 4)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/4656',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 7424,
#   'name': 'VEGFC',
#   'data': {'description': 'vascular endothelial growth factor C',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/7424',
#    'chromosome': '4'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0006726',
#   'name': 'eye pigment biosynthetic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0006726'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0025193',
#   'name': 'Melancholia',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0025193'}},
#  {'kind': 'Gene',
#   'identifier': 6821,
#   'name': 'SUOX',
#   'data': {'description': 'sulfite oxidase',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/6821',
#    'chromosome': '12'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0030619',
#   'name': 'U1 snRNA binding',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0030619'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0578687',
#   'name': 'Sore eye',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0578687'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0018812',
#   'name': '3-hydroxyacyl-CoA dehydratase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0018812'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010243',
#   'name': 'response to organonitrogen compound',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010243'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010455',
#   'name': 'positive regulation of cell fate commitment',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010455'}},
#  {'kind': 'Gene',
#   'identifier': 4154,
#   'name': 'MBNL1',
#   'data': {'description': 'muscleblind-like splicing regulator 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/4154',
#    'chromosome': '3'}},
#  {'kind': 'Gene',
#   'identifier': 55200,
#   'name': 'PLEKHG6',
#   'data': {'description': 'pleckstrin homology domain containing, family G (with RhoGef domain) member 6',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/55200',
#    'chromosome': '12'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0919671',
#   'name': 'Subileus',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0919671'}},
#  {'kind': 'Gene',
#   'identifier': 25790,
#   'name': 'CFAP45',
#   'data': {'description': 'cilia and flagella associated protein 45',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/25790',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 10276,
#   'name': 'NET1',
#   'data': {'description': 'neuroepithelial cell transforming 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10276',
#    'chromosome': '10'}},
#  {'kind': 'Gene',
#   'identifier': 2527,
#   'name': 'FUT5',
#   'data': {'description': 'fucosyltransferase 5 (alpha (1,3) fucosyltransferase)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/2527',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0044362',
#   'name': 'negative regulation of molecular function in other organism',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0044362'}},
#  {'kind': 'Gene',
#   'identifier': 8633,
#   'name': 'UNC5C',
#   'data': {'description': 'unc-5 homolog C (C. elegans)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/8633',
#    'chromosome': '4'}},
#  {'kind': 'Gene',
#   'identifier': 1908,
#   'name': 'EDN3',
#   'data': {'description': 'endothelin 3',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/1908',
#    'chromosome': '20'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0060488',
#   'name': 'orthogonal dichotomous subdivision of terminal units involved in lung branching morphogenesis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0060488'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0237849',
#   'name': 'Skin exfoliation',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0237849'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00201',
#   'name': 'Caffeine',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=RYYVLZVUVIJVGH-UHFFFAOYSA-N',
#    'inchi': 'InChI=1S/C8H10N4O2/c1-10-4-9-6-5(10)7(13)12(3)8(14)11(6)2/h4H,1-3H3',
#    'url': 'http://www.drugbank.ca/drugs/DB00201'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0071169',
#   'name': 'establishment of protein localization to chromatin',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0071169'}},
#  {'kind': 'Gene',
#   'identifier': 84811,
#   'name': 'BUD13',
#   'data': {'description': 'BUD13 homolog (S. cerevisiae)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/84811',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 100506627,
#   'name': 'DCDC5',
#   'data': {'description': 'doublecortin domain containing 5',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/100506627',
#    'chromosome': '11'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0042267',
#   'name': 'Vaginal inflammation',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0042267'}},
#  {'kind': 'Gene',
#   'identifier': 6233,
#   'name': 'RPS27A',
#   'data': {'description': 'ribosomal protein S27a',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/6233',
#    'chromosome': '2'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0048640',
#   'name': 'negative regulation of developmental growth',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0048640'}},
#  {'kind': 'Gene',
#   'identifier': 90933,
#   'name': 'TRIM41',
#   'data': {'description': 'tripartite motif containing 41',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/90933',
#    'chromosome': '5'}},
#  {'kind': 'Pathway',
#   'identifier': 'PC7_3805',
#   'name': 'FCERI mediated Ca+2 mobilization',
#   'data': {'license': 'CC BY 4.0', 'source': 'Reactome via Pathway Commons'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0036296',
#   'name': 'response to increased oxygen levels',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0036296'}},
#  {'kind': 'Compound',
#   'identifier': 'DB09019',
#   'name': 'Bromhexine',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=OJGDCBLYJGHCIH-UHFFFAOYSA-N',
#    'inchi': 'InChI=1S/C14H20Br2N2/c1-18(12-5-3-2-4-6-12)9-10-7-11(15)8-13(16)14(10)17/h7-8,12H,2-6,9,17H2,1H3',
#    'url': 'http://www.drugbank.ca/drugs/DB09019'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C1141885',
#   'name': 'Sclerosing encapsulating peritonitis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C1141885'}},
#  {'kind': 'Anatomy',
#   'identifier': 'UBERON:0001533',
#   'name': 'subclavian artery',
#   'data': {'source': 'Uberon',
#    'license': 'CC BY 3.0',
#    'url': 'http://purl.obolibrary.org/obo/UBERON_0001533',
#    'mesh_id': 'D013348'}},
#  {'kind': 'Gene',
#   'identifier': 4606,
#   'name': 'MYBPC2',
#   'data': {'description': 'myosin binding protein C, fast type',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/4606',
#    'chromosome': '19'}},
#  {'kind': 'Anatomy',
#   'identifier': 'UBERON:0000020',
#   'name': 'sense organ',
#   'data': {'source': 'Uberon',
#    'bto_id': 'BTO:0000202',
#    'license': 'CC BY 3.0',
#    'url': 'http://purl.obolibrary.org/obo/UBERON_0000020',
#    'mesh_id': 'D012679'}},
#  {'kind': 'Pathway',
#   'identifier': 'PC7_3964',
#   'name': 'Formation of annular gap junctions',
#   'data': {'license': 'CC BY 4.0', 'source': 'Reactome via Pathway Commons'}},
#  {'kind': 'Gene',
#   'identifier': 27250,
#   'name': 'PDCD4',
#   'data': {'description': 'programmed cell death 4 (neoplastic transformation inhibitor)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/27250',
#    'chromosome': '10'}},
#  {'kind': 'Gene',
#   'identifier': 10712,
#   'name': 'FAM189B',
#   'data': {'description': 'family with sequence similarity 189, member B',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10712',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 3987,
#   'name': 'LIMS1',
#   'data': {'description': 'LIM and senescent cell antigen-like domains 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/3987',
#    'chromosome': '2'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0048145',
#   'name': 'regulation of fibroblast proliferation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0048145'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:1990743',
#   'name': 'protein sialylation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_1990743'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0000784',
#   'name': 'nuclear chromosome, telomeric region',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0000784'}},
#  {'kind': 'Gene',
#   'identifier': 147906,
#   'name': 'DACT3',
#   'data': {'description': 'dishevelled-binding antagonist of beta-catenin 3',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/147906',
#    'chromosome': '19'}},
#  {'kind': 'Gene',
#   'identifier': 10109,
#   'name': 'ARPC2',
#   'data': {'description': 'actin related protein 2/3 complex, subunit 2, 34kDa',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10109',
#    'chromosome': '2'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0009062',
#   'name': 'fatty acid catabolic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0009062'}},
#  {'kind': 'Compound',
#   'identifier': 'DB01267',
#   'name': 'Paliperidone',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=PMXMIIMHBWHSKN-UHFFFAOYSA-N',
#    'inchi': 'InChI=1S/C23H27FN4O3/c1-14-17(23(30)28-9-2-3-19(29)22(28)25-14)8-12-27-10-6-15(7-11-27)21-18-5-4-16(24)13-20(18)31-26-21/h4-5,13,15,19,29H,2-3,6-12H2,1H3',
#    'url': 'http://www.drugbank.ca/drugs/DB01267'}},
#  {'kind': 'Gene',
#   'identifier': 105378955,
#   'name': 'LOC105378955',
#   'data': {'description': 'tripartite motif-containing protein LOC642612',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/105378955',
#    'chromosome': '11'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0060474',
#   'name': 'positive regulation of sperm motility involved in capacitation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0060474'}},
#  {'kind': 'Gene',
#   'identifier': 717,
#   'name': 'C2',
#   'data': {'description': 'complement component 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/717',
#    'chromosome': '6'}},
#  {'kind': 'Gene',
#   'identifier': 57464,
#   'name': 'STRIP2',
#   'data': {'description': 'striatin interacting protein 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/57464',
#    'chromosome': '7'}},
#  {'kind': 'Gene',
#   'identifier': 84239,
#   'name': 'ATP13A4',
#   'data': {'description': 'ATPase type 13A4',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/84239',
#    'chromosome': '3'}},
#  {'kind': 'Gene',
#   'identifier': 29948,
#   'name': 'OSGIN1',
#   'data': {'description': 'oxidative stress induced growth inhibitor 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/29948',
#    'chromosome': '16'}},
#  {'kind': 'Gene',
#   'identifier': 23223,
#   'name': 'RRP12',
#   'data': {'description': 'ribosomal RNA processing 12 homolog (S. cerevisiae)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/23223',
#    'chromosome': '10'}},
#  {'kind': 'Gene',
#   'identifier': 7709,
#   'name': 'ZBTB17',
#   'data': {'description': 'zinc finger and BTB domain containing 17',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/7709',
#    'chromosome': '1'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0019212',
#   'name': 'phosphatase inhibitor activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0019212'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0339807',
#   'name': 'House dust allergy',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0339807'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0097104',
#   'name': 'postsynaptic membrane assembly',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0097104'}},
#  {'kind': 'Gene',
#   'identifier': 125893,
#   'name': 'ZNF816',
#   'data': {'description': 'zinc finger protein 816',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/125893',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:1990776',
#   'name': 'response to angiotensin',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_1990776'}},
#  {'kind': 'Pathway',
#   'identifier': 'PC7_1532',
#   'name': 'Activation of G protein gated Potassium channels',
#   'data': {'license': 'CC BY 4.0', 'source': 'Reactome via Pathway Commons'}},
#  {'kind': 'Gene',
#   'identifier': 362,
#   'name': 'AQP5',
#   'data': {'description': 'aquaporin 5',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/362',
#    'chromosome': '12'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0001539',
#   'name': 'cilium or flagellum-dependent cell motility',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0001539'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00174',
#   'name': 'L-Asparagine',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=DCXYFEDJOCDNAF-REOHCLBHSA-N',
#    'inchi': 'InChI=1S/C4H8N2O3/c5-2(4(8)9)1-3(6)7/h2H,1,5H2,(H2,6,7)(H,8,9)/t2-/m0/s1',
#    'url': 'http://www.drugbank.ca/drugs/DB00174'}},
#  {'kind': 'Anatomy',
#   'identifier': 'UBERON:0001690',
#   'name': 'ear',
#   'data': {'source': 'Uberon',
#    'bto_id': 'BTO:0000368',
#    'license': 'CC BY 3.0',
#    'url': 'http://purl.obolibrary.org/obo/UBERON_0001690',
#    'mesh_id': 'D004423'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0003072',
#   'name': 'renal control of peripheral vascular resistance involved in regulation of systemic arterial blood pressure',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0003072'}},
#  {'kind': 'Symptom',
#   'identifier': 'D020150',
#   'name': 'Chorea Gravidarum',
#   'data': {'source': 'MeSH',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/mesh/D020150'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0008360',
#   'name': 'regulation of cell shape',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0008360'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0034677',
#   'name': 'integrin alpha7-beta1 complex',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0034677'}},
#  {'kind': 'Gene',
#   'identifier': 80196,
#   'name': 'RNF34',
#   'data': {'description': 'ring finger protein 34, E3 ubiquitin protein ligase',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/80196',
#    'chromosome': '12'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0004658',
#   'name': 'propionyl-CoA carboxylase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0004658'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0235222',
#   'name': 'Diastolic hypertension',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0235222'}},
#  {'kind': 'Gene',
#   'identifier': 27121,
#   'name': 'DKK4',
#   'data': {'description': 'dickkopf WNT signaling pathway inhibitor 4',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/27121',
#    'chromosome': '8'}},
#  {'kind': 'Gene',
#   'identifier': 9521,
#   'name': 'EEF1E1',
#   'data': {'description': 'eukaryotic translation elongation factor 1 epsilon 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/9521',
#    'chromosome': '6'}},
#  {'kind': 'Gene',
#   'identifier': 2796,
#   'name': 'GNRH1',
#   'data': {'description': 'gonadotropin-releasing hormone 1 (luteinizing-releasing hormone)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/2796',
#    'chromosome': '8'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0072595',
#   'name': 'maintenance of protein localization in organelle',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0072595'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0043407',
#   'name': 'negative regulation of MAP kinase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0043407'}},
#  {'kind': 'Gene',
#   'identifier': 79577,
#   'name': 'CDC73',
#   'data': {'description': 'cell division cycle 73',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/79577',
#    'chromosome': '1'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0850638',
#   'name': 'Infected bites',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0850638'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0035384',
#   'name': 'thioester biosynthetic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0035384'}},
#  {'kind': 'Gene',
#   'identifier': 51191,
#   'name': 'HERC5',
#   'data': {'description': 'HECT and RLD domain containing E3 ubiquitin protein ligase 5',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/51191',
#    'chromosome': '4'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010758',
#   'name': 'regulation of macrophage chemotaxis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010758'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C1456329',
#   'name': 'Stomach dilation procedure',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C1456329'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0032090',
#   'name': 'Pyrin domain binding',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0032090'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0017181',
#   'name': 'Gastrointestinal haemorrhage',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0017181'}},
#  {'kind': 'Gene',
#   'identifier': 5494,
#   'name': 'PPM1A',
#   'data': {'description': 'protein phosphatase, Mg2+/Mn2+ dependent, 1A',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/5494',
#    'chromosome': '14'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C3160759',
#   'name': 'Tumour cell mobilisation',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C3160759'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00697',
#   'name': 'Tizanidine',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=XFYDIVBRZNQMJC-UHFFFAOYSA-N',
#    'inchi': 'InChI=1S/C9H8ClN5S/c10-5-1-2-6-8(15-16-14-6)7(5)13-9-11-3-4-12-9/h1-2H,3-4H2,(H2,11,12,13)',
#    'url': 'http://www.drugbank.ca/drugs/DB00697'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0684275',
#   'name': 'Haemophilia',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0684275'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00137',
#   'name': 'Xanthophyll',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=KBPHJBAIARWVSC-DKLMTRRASA-N',
#    'inchi': 'InChI=1S/C40H56O2/c1-29(17-13-19-31(3)21-23-37-33(5)25-35(41)27-39(37,7)8)15-11-12-16-30(2)18-14-20-32(4)22-24-38-34(6)26-36(42)28-40(38,9)10/h11-25,35-37,41-42H,26-28H2,1-10H3/b12-11+,17-13+,18-14+,23-21+,24-22+,29-15+,30-16+,31-19+,32-20+',
#    'url': 'http://www.drugbank.ca/drugs/DB00137'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0098798',
#   'name': 'mitochondrial protein complex',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0098798'}},
#  {'kind': 'Gene',
#   'identifier': 54897,
#   'name': 'CASZ1',
#   'data': {'description': 'castor zinc finger 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/54897',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 219469,
#   'name': 'OR8H1',
#   'data': {'description': 'olfactory receptor, family 8, subfamily H, member 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/219469',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 222696,
#   'name': 'ZSCAN23',
#   'data': {'description': 'zinc finger and SCAN domain containing 23',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/222696',
#    'chromosome': '6'}},
#  {'kind': 'Gene',
#   'identifier': 26511,
#   'name': 'CHIC2',
#   'data': {'description': 'cysteine-rich hydrophobic domain 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/26511',
#    'chromosome': '4'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:1900218',
#   'name': 'negative regulation of apoptotic process involved in metanephric nephron tubule development',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_1900218'}},
#  {'kind': 'Gene',
#   'identifier': 2208,
#   'name': 'FCER2',
#   'data': {'description': 'Fc fragment of IgE, low affinity II, receptor for (CD23)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/2208',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0007212',
#   'name': 'dopamine receptor signaling pathway',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0007212'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0090265',
#   'name': 'positive regulation of immune complex clearance by monocytes and macrophages',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0090265'}},
#  {'kind': 'Gene',
#   'identifier': 79005,
#   'name': 'SCNM1',
#   'data': {'description': 'sodium channel modifier 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/79005',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 121278,
#   'name': 'TPH2',
#   'data': {'description': 'tryptophan hydroxylase 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/121278',
#    'chromosome': '12'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0743668',
#   'name': 'Limb injury',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0743668'}},
#  {'kind': 'Gene',
#   'identifier': 8330,
#   'name': 'HIST1H2AK',
#   'data': {'description': 'histone cluster 1, H2ak',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/8330',
#    'chromosome': '6'}},
#  {'kind': 'Gene',
#   'identifier': 1605,
#   'name': 'DAG1',
#   'data': {'description': 'dystroglycan 1 (dystrophin-associated glycoprotein 1)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/1605',
#    'chromosome': '3'}},
#  {'kind': 'Pathway',
#   'identifier': 'PC7_4961',
#   'name': 'Leukotriene receptors',
#   'data': {'license': 'CC BY 4.0', 'source': 'Reactome via Pathway Commons'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:2000674',
#   'name': 'regulation of type B pancreatic cell apoptotic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_2000674'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0085612',
#   'name': 'Ventricular arrhythmia',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0085612'}},
#  {'kind': 'Gene',
#   'identifier': 11004,
#   'name': 'KIF2C',
#   'data': {'description': 'kinesin family member 2C',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/11004',
#    'chromosome': '1'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0033178',
#   'name': 'proton-transporting two-sector ATPase complex, catalytic domain',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0033178'}},
#  {'kind': 'Gene',
#   'identifier': 30836,
#   'name': 'DNTTIP2',
#   'data': {'description': 'deoxynucleotidyltransferase, terminal, interacting protein 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/30836',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 102725035,
#   'name': 'LOC102725035',
#   'data': {'description': 'leukocyte immunoglobulin-like receptor subfamily B member 3',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/102725035',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0007259',
#   'name': 'JAK-STAT cascade',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0007259'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0070579',
#   'name': 'methylcytosine dioxygenase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0070579'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0044804',
#   'name': 'nucleophagy',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0044804'}},
#  {'kind': 'Gene',
#   'identifier': 284612,
#   'name': 'SYPL2',
#   'data': {'description': 'synaptophysin-like 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/284612',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 6954,
#   'name': 'TCP11',
#   'data': {'description': 't-complex 11, testis-specific',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/6954',
#    'chromosome': '6'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0051183',
#   'name': 'vitamin transporter activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0051183'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0008263',
#   'name': 'pyrimidine-specific mismatch base pair DNA N-glycosylase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0008263'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0030502',
#   'name': 'negative regulation of bone mineralization',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0030502'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0000727',
#   'name': 'double-strand break repair via break-induced replication',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0000727'}},
#  {'kind': 'Compound',
#   'identifier': 'DB08834',
#   'name': 'Tauroursodeoxycholic acid',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=BHTRKEVKTKCXOH-CNHNFURNNA-N',
#    'inchi': 'InChI=1/C26H45NO6S/c1-16(4-7-23(30)27-12-13-34(31,32)33)19-5-6-20-24-21(9-11-26(19,20)3)25(2)10-8-18(28)14-17(25)15-22(24)29/h16-22,24,28-29H,4-15H2,1-3H3,(H,27,30)(H,31,32,33)/t16?,17-,18+,19?,20-,21-,22-,24-,25-,26+/s2',
#    'url': 'http://www.drugbank.ca/drugs/DB08834'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0051012',
#   'name': 'microtubule sliding',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0051012'}},
#  {'kind': 'Gene',
#   'identifier': 28990,
#   'name': 'ASTE1',
#   'data': {'description': 'asteroid homolog 1 (Drosophila)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/28990',
#    'chromosome': '3'}},
#  {'kind': 'Gene',
#   'identifier': 4303,
#   'name': 'FOXO4',
#   'data': {'description': 'forkhead box O4',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/4303',
#    'chromosome': 'X'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0040210',
#   'name': 'VT',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0040210'}},
#  {'kind': 'Gene',
#   'identifier': 89857,
#   'name': 'KLHL6',
#   'data': {'description': 'kelch-like family member 6',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/89857',
#    'chromosome': '3'}},
#  {'kind': 'Gene',
#   'identifier': 79665,
#   'name': 'DHX40',
#   'data': {'description': 'DEAH (Asp-Glu-Ala-His) box polypeptide 40',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/79665',
#    'chromosome': '17'}},
#  {'kind': 'Gene',
#   'identifier': 25923,
#   'name': 'ATL3',
#   'data': {'description': 'atlastin GTPase 3',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/25923',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 10409,
#   'name': 'BASP1',
#   'data': {'description': 'brain abundant, membrane attached signal protein 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10409',
#    'chromosome': '5'}},
#  {'kind': 'Gene',
#   'identifier': 3684,
#   'name': 'ITGAM',
#   'data': {'description': 'integrin, alpha M (complement component 3 receptor 3 subunit)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/3684',
#    'chromosome': '16'}},
#  {'kind': 'Pathway',
#   'identifier': 'PC7_2651',
#   'name': 'Cobalamin (Cbl, vitamin B12) transport and metabolism',
#   'data': {'license': 'CC BY 4.0', 'source': 'Reactome via Pathway Commons'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00737',
#   'name': 'Meclizine',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=OCJYIGYOJCODJL-UHFFFAOYSA-N',
#    'inchi': 'InChI=1S/C25H27ClN2/c1-20-6-5-7-21(18-20)19-27-14-16-28(17-15-27)25(22-8-3-2-4-9-22)23-10-12-24(26)13-11-23/h2-13,18,25H,14-17,19H2,1H3',
#    'url': 'http://www.drugbank.ca/drugs/DB00737'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0071284',
#   'name': 'cellular response to lead ion',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0071284'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010692',
#   'name': 'regulation of alkaline phosphatase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010692'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0008105',
#   'name': 'asymmetric protein localization',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0008105'}},
#  {'kind': 'Disease',
#   'identifier': 'DOID:14227',
#   'name': 'azoospermia',
#   'data': {'source': 'Disease Ontology',
#    'license': 'CC BY 3.0',
#    'url': 'http://purl.obolibrary.org/obo/DOID_14227'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0007140',
#   'name': 'male meiosis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0007140'}},
#  {'kind': 'Gene',
#   'identifier': 9806,
#   'name': 'SPOCK2',
#   'data': {'description': 'sparc/osteonectin, cwcv and kazal-like domains proteoglycan (testican) 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/9806',
#    'chromosome': '10'}},
#  {'kind': 'Gene',
#   'identifier': 2041,
#   'name': 'EPHA1',
#   'data': {'description': 'EPH receptor A1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/2041',
#    'chromosome': '7'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:1901224',
#   'name': 'positive regulation of NIK/NF-kappaB signaling',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_1901224'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0392676',
#   'name': 'Hyperpyrexia',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0392676'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0035441',
#   'name': 'cell migration involved in vasculogenesis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0035441'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0009629',
#   'name': 'response to gravity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0009629'}},
#  {'kind': 'Gene',
#   'identifier': 391004,
#   'name': 'PRAMEF17',
#   'data': {'description': 'PRAME family member 17',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/391004',
#    'chromosome': '1'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0032880',
#   'name': 'regulation of protein localization',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0032880'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0014824',
#   'name': 'artery smooth muscle contraction',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0014824'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0003079',
#   'name': 'Pupils unequal',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0003079'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0090204',
#   'name': 'protein localization to nuclear pore',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0090204'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010980',
#   'name': 'positive regulation of vitamin D 24-hydroxylase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010980'}},
#  {'kind': 'Gene',
#   'identifier': 84944,
#   'name': 'MAEL',
#   'data': {'description': 'maelstrom spermatogenic transposon silencer',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/84944',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 146227,
#   'name': 'BEAN1',
#   'data': {'description': 'brain expressed, associated with NEDD4, 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/146227',
#    'chromosome': '16'}},
#  {'kind': 'Gene',
#   'identifier': 6382,
#   'name': 'SDC1',
#   'data': {'description': 'syndecan 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/6382',
#    'chromosome': '2'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C1175175',
#   'name': 'Severe acute respiratory syndrome',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C1175175'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0032449',
#   'name': 'CBM complex',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0032449'}},
#  {'kind': 'Gene',
#   'identifier': 5763,
#   'name': 'PTMS',
#   'data': {'description': 'parathymosin',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/5763',
#    'chromosome': '12'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0151500',
#   'name': 'Anticholinergic syndrome',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0151500'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0098559',
#   'name': 'cytoplasmic side of early endosome membrane',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0098559'}},
#  {'kind': 'Gene',
#   'identifier': 158471,
#   'name': 'PRUNE2',
#   'data': {'description': 'prune homolog 2 (Drosophila)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/158471',
#    'chromosome': '9'}},
#  {'kind': 'Gene',
#   'identifier': 3096,
#   'name': 'HIVEP1',
#   'data': {'description': 'human immunodeficiency virus type I enhancer binding protein 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/3096',
#    'chromosome': '6'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C1963790',
#   'name': 'Vulvovaginal burning sensation',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C1963790'}},
#  {'kind': 'Gene',
#   'identifier': 100289678,
#   'name': 'ZNF783',
#   'data': {'description': 'zinc finger family member 783',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/100289678',
#    'chromosome': '7'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:2000739',
#   'name': 'regulation of mesenchymal stem cell differentiation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_2000739'}},
#  {'kind': 'Compound',
#   'identifier': 'DB00377',
#   'name': 'Palonosetron',
#   'data': {'license': 'CC BY-NC 4.0',
#    'source': 'DrugBank',
#    'inchikey': 'InChIKey=CPZBLNMUGSZIPR-DOTOQJQBSA-N',
#    'inchi': 'InChI=1S/C19H24N2O/c22-19-16-6-2-4-14-3-1-5-15(18(14)16)11-21(19)17-12-20-9-7-13(17)8-10-20/h2,4,6,13,15,17H,1,3,5,7-12H2/t15-,17+/m0/s1',
#    'url': 'http://www.drugbank.ca/drugs/DB00377'}},
#  {'kind': 'Gene',
#   'identifier': 79893,
#   'name': 'GGNBP2',
#   'data': {'description': 'gametogenetin binding protein 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/79893',
#    'chromosome': '17'}},
#  {'kind': 'Pharmacologic Class',
#   'identifier': 'N0000007632',
#   'name': 'Thyroxine',
#   'data': {'class_type': 'Chemical/Ingredient',
#    'source': 'FDA via DrugCentral',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.bioontology.org/ontology/NDFRT/N0000007632'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0040261',
#   'name': 'Onychomycosis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0040261'}},
#  {'kind': 'Gene',
#   'identifier': 9218,
#   'name': 'VAPA',
#   'data': {'description': 'VAMP (vesicle-associated membrane protein)-associated protein A, 33kDa',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/9218',
#    'chromosome': '18'}},
#  {'kind': 'Gene',
#   'identifier': 1469,
#   'name': 'CST1',
#   'data': {'description': 'cystatin SN',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/1469',
#    'chromosome': '20'}},
#  {'kind': 'Gene',
#   'identifier': 51491,
#   'name': 'NOP16',
#   'data': {'description': 'NOP16 nucleolar protein',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/51491',
#    'chromosome': '5'}},
#  {'kind': 'Gene',
#   'identifier': 102724164,
#   'name': 'LOC102724164',
#   'data': {'description': 'uncharacterized LOC102724164',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/102724164',
#    'chromosome': '17'}},
#  {'kind': 'Gene',
#   'identifier': 101929983,
#   'name': 'LOC101929983',
#   'data': {'description': 'PRAME family member 9/15-like',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/101929983',
#    'chromosome': '1'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:2000138',
#   'name': 'positive regulation of cell proliferation involved in heart morphogenesis',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_2000138'}},
#  {'kind': 'Gene',
#   'identifier': 128272,
#   'name': 'ARHGEF19',
#   'data': {'description': 'Rho guanine nucleotide exchange factor (GEF) 19',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/128272',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 374918,
#   'name': 'IGFL1',
#   'data': {'description': 'IGF-like family member 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/374918',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0090077',
#   'name': 'foam cell differentiation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0090077'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0014358',
#   'name': 'Pseudomembranous enterocolitis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0014358'}},
#  {'kind': 'Gene',
# ...
#    'url': 'http://purl.obolibrary.org/obo/GO_0036037'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0036312',
#   'name': 'phosphatidylinositol 3-kinase regulatory subunit binding',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0036312'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0010414',
#   'name': 'Cryptococcosis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0010414'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0149744',
#   'name': 'Oral lesion',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0149744'}},
#  {'kind': 'Gene',
#   'identifier': 10769,
#   'name': 'PLK2',
#   'data': {'description': 'polo-like kinase 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10769',
#    'chromosome': '5'}},
#  {'kind': 'Gene',
#   'identifier': 3020,
#   'name': 'H3F3A',
#   'data': {'description': 'H3 histone, family 3A',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/3020',
#    'chromosome': '1'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0338573',
#   'name': 'Intracranial venous sinus thrombosis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0338573'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C1142135',
#   'name': 'Muscle relaxant therapy',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C1142135'}},
#  {'kind': 'Gene',
#   'identifier': 5621,
#   'name': 'PRNP',
#   'data': {'description': 'prion protein',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/5621',
#    'chromosome': '20'}},
#  {'kind': 'Gene',
#   'identifier': 79801,
#   'name': 'SHCBP1',
#   'data': {'description': 'SHC SH2-domain binding protein 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/79801',
#    'chromosome': '16'}},
#  {'kind': 'Gene',
#   'identifier': 9142,
#   'name': 'TMEM257',
#   'data': {'description': 'transmembrane protein 257',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/9142',
#    'chromosome': 'X'}},
#  {'kind': 'Gene',
#   'identifier': 353,
#   'name': 'APRT',
#   'data': {'description': 'adenine phosphoribosyltransferase',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/353',
#    'chromosome': '16'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0019551',
#   'name': 'glutamate catabolic process to 2-oxoglutarate',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0019551'}},
#  {'kind': 'Gene',
#   'identifier': 22859,
#   'name': 'ADGRL1',
#   'data': {'description': 'adhesion G protein-coupled receptor L1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/22859',
#    'chromosome': '19'}},
#  {'kind': 'Gene',
#   'identifier': 7345,
#   'name': 'UCHL1',
#   'data': {'description': 'ubiquitin carboxyl-terminal esterase L1 (ubiquitin thiolesterase)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/7345',
#    'chromosome': '4'}},
#  {'kind': 'Gene',
#   'identifier': 223117,
#   'name': 'SEMA3D',
#   'data': {'description': 'sema domain, immunoglobulin domain (Ig), short basic domain, secreted, (semaphorin) 3D',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/223117',
#    'chromosome': '7'}},
#  {'kind': 'Gene',
#   'identifier': 338675,
#   'name': 'OR5AP2',
#   'data': {'description': 'olfactory receptor, family 5, subfamily AP, member 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/338675',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 388697,
#   'name': 'HRNR',
#   'data': {'description': 'hornerin',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/388697',
#    'chromosome': '1'}},
#  {'kind': 'Gene',
#   'identifier': 28981,
#   'name': 'IFT81',
#   'data': {'description': 'intraflagellar transport 81',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/28981',
#    'chromosome': '12'}},
#  {'kind': 'Gene',
#   'identifier': 137814,
#   'name': 'NKX2-6',
#   'data': {'description': 'NK2 homeobox 6',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/137814',
#    'chromosome': '8'}},
#  {'kind': 'Gene',
#   'identifier': 55740,
#   'name': 'ENAH',
#   'data': {'description': 'enabled homolog (Drosophila)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/55740',
#    'chromosome': '1'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0052650',
#   'name': 'NADP-retinol dehydrogenase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0052650'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0016242',
#   'name': 'Vitreous floaters',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0016242'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0097433',
#   'name': 'dense body',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0097433'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0004320',
#   'name': 'oleoyl-[acyl-carrier-protein] hydrolase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0004320'}},
#  {'kind': 'Gene',
#   'identifier': 5099,
#   'name': 'PCDH7',
#   'data': {'description': 'protocadherin 7',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/5099',
#    'chromosome': '4'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0015111',
#   'name': 'iodide transmembrane transporter activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0015111'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0046322',
#   'name': 'negative regulation of fatty acid oxidation',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0046322'}},
#  {'kind': 'Gene',
#   'identifier': 11221,
#   'name': 'DUSP10',
#   'data': {'description': 'dual specificity phosphatase 10',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/11221',
#    'chromosome': '1'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0853811',
#   'name': 'Croup infectious',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0853811'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0010666',
#   'name': 'positive regulation of cardiac muscle cell apoptotic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0010666'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0051494',
#   'name': 'negative regulation of cytoskeleton organization',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0051494'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0015644',
#   'name': 'Fasciculation',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0015644'}},
#  {'kind': 'Gene',
#   'identifier': 8554,
#   'name': 'PIAS1',
#   'data': {'description': 'protein inhibitor of activated STAT, 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/8554',
#    'chromosome': '15'}},
#  {'kind': 'Gene',
#   'identifier': 1829,
#   'name': 'DSG2',
#   'data': {'description': 'desmoglein 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/1829',
#    'chromosome': '18'}},
#  {'kind': 'Gene',
#   'identifier': 200909,
#   'name': 'HTR3D',
#   'data': {'description': '5-hydroxytryptamine (serotonin) receptor 3D, ionotropic',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/200909',
#    'chromosome': '3'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0855440',
#   'name': 'Pancreatic enzymes abnormal',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0855440'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0002591',
#   'name': 'positive regulation of antigen processing and presentation of peptide antigen via MHC class I',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0002591'}},
#  {'kind': 'Gene',
#   'identifier': 125981,
#   'name': 'ACER1',
#   'data': {'description': 'alkaline ceramidase 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/125981',
#    'chromosome': '19'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0051353',
#   'name': 'positive regulation of oxidoreductase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0051353'}},
#  {'kind': 'Pathway',
#   'identifier': 'WP61_r78592',
#   'name': 'Notch Signaling Pathway',
#   'data': {'license': 'CC BY 3.0',
#    'source': 'WikiPathways',
#    'url': 'http://www.wikipathways.org/instance/WP61_r78592'}},
#  {'kind': 'Gene',
#   'identifier': 6154,
#   'name': 'RPL26',
#   'data': {'description': 'ribosomal protein L26',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/6154',
#    'chromosome': '17'}},
#  {'kind': 'Gene',
#   'identifier': 63941,
#   'name': 'NECAB3',
#   'data': {'description': 'N-terminal EF-hand calcium binding protein 3',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/63941',
#    'chromosome': '20'}},
#  {'kind': 'Gene',
#   'identifier': 101929601,
#   'name': 'LOC101929601',
#   'data': {'description': 'putative exonuclease GOR',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/101929601',
#    'chromosome': '8'}},
#  {'kind': 'Gene',
#   'identifier': 4123,
#   'name': 'MAN2C1',
#   'data': {'description': 'mannosidase, alpha, class 2C, member 1',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/4123',
#    'chromosome': '15'}},
#  {'kind': 'Gene',
#   'identifier': 206412,
#   'name': 'C6orf163',
#   'data': {'description': 'chromosome 6 open reading frame 163',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/206412',
#    'chromosome': '6'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0854453',
#   'name': 'Escherichia sepsis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0854453'}},
#  {'kind': 'Cellular Component',
#   'identifier': 'GO:0014069',
#   'name': 'postsynaptic density',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0014069'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0235169',
#   'name': 'Excitability',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0235169'}},
#  {'kind': 'Gene',
#   'identifier': 266743,
#   'name': 'NPAS4',
#   'data': {'description': 'neuronal PAS domain protein 4',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/266743',
#    'chromosome': '11'}},
#  {'kind': 'Gene',
#   'identifier': 54549,
#   'name': 'SDK2',
#   'data': {'description': 'sidekick cell adhesion molecule 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/54549',
#    'chromosome': '17'}},
#  {'kind': 'Gene',
#   'identifier': 441024,
#   'name': 'MTHFD2L',
#   'data': {'description': 'methylenetetrahydrofolate dehydrogenase (NADP+ dependent) 2-like',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/441024',
#    'chromosome': '4'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0071675',
#   'name': 'regulation of mononuclear cell migration',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0071675'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0046133',
#   'name': 'pyrimidine ribonucleoside catabolic process',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0046133'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0030451',
#   'name': 'regulation of complement activation, alternative pathway',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0030451'}},
#  {'kind': 'Gene',
#   'identifier': 353140,
#   'name': 'LCE2C',
#   'data': {'description': 'late cornified envelope 2C',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/353140',
#    'chromosome': '1'}},
#  {'kind': 'Symptom',
#   'identifier': 'D000370',
#   'name': 'Ageusia',
#   'data': {'source': 'MeSH',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/mesh/D000370'}},
#  {'kind': 'Gene',
#   'identifier': 10633,
#   'name': 'RASL10A',
#   'data': {'description': 'RAS-like, family 10, member A',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/10633',
#    'chromosome': '22'}},
#  {'kind': 'Gene',
#   'identifier': 3908,
#   'name': 'LAMA2',
#   'data': {'description': 'laminin, alpha 2',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/3908',
#    'chromosome': '6'}},
#  {'kind': 'Biological Process',
#   'identifier': 'GO:0090238',
#   'name': 'positive regulation of arachidonic acid secretion',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0090238'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0700639',
#   'name': 'Congenital hypertrophic pyloric stenosis',
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0700639'}},
#  {'kind': 'Gene',
#   'identifier': 1241,
#   'name': 'LTB4R',
#   'data': {'description': 'leukotriene B4 receptor',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/1241',
#    'chromosome': '14'}},
#  {'kind': 'Gene',
#   'identifier': 51279,
#   'name': 'C1RL',
#   'data': {'description': 'complement component 1, r subcomponent-like',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/51279',
#    'chromosome': '12'}},
#  {'kind': 'Gene',
#   'identifier': 105371127,
#   'name': 'LOC105371127',
#   'data': {'description': 'uncharacterized LOC105371127',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/105371127',
#    'chromosome': '16'}},
#  {'kind': 'Side Effect',
#   'identifier': 'C0010346',
#   'name': "Crohn's disease",
#   'data': {'source': 'UMLS via SIDER 4.1',
#    'license': 'CC BY-NC-SA 4.0',
#    'url': 'http://identifiers.org/umls/C0010346'}},
#  {'kind': 'Gene',
#   'identifier': 638,
#   'name': 'BIK',
#   'data': {'description': 'BCL2-interacting killer (apoptosis-inducing)',
#    'source': 'Entrez Gene',
#    'license': 'CC0 1.0',
#    'url': 'http://identifiers.org/ncbigene/638',
#    'chromosome': '22'}},
#  {'kind': 'Molecular Function',
#   'identifier': 'GO:0051747',
#   'name': 'cytosine C-5 DNA demethylase activity',
#   'data': {'source': 'Gene Ontology',
#    'license': 'CC BY 4.0',
#    'url': 'http://purl.obolibrary.org/obo/GO_0051747'}},
#  ...]

# %%
metaedges = {
    "Anatomy-downregulates-Gene": "The Gene is under-expressed in the Anatomy in post-juvenile adult human samples according to Bgee",
    "Anatomy-expresses-Gene": "The Gene is over-expressed in the Anatomy according to Bgee or TISSUES",
    "Anatomy-upregulates-Gene": "The Gene is over-expressed in the Anatomy in post-juvenile adult human samples according to Bgee",
    "Compound-binds-Gene": "The Compound physically binds to the Gene's protein product according to BindingDB, DrugBank, or DrugCentral",
    "Compound-causes-Side Effect": "The Compound can cause the Side Effect according to a drug label in SIDER 4.1",
    "Compound-downregulates-Gene": "The Gene is under-expressed in samples exposed to the Compound according to a consensus signature from LINCS L1000",
    "Compound-palliates-Disease": "The Compound is a symptomatic indication for the Disease (i.e. the Compound treats a significant symptom of the Disease) according to PharmacotherapyDB",
    "Compound-resembles-Compound": "The Compounds are chemical similar to each other: Their extended connectivity fingerprints have a Dice coefficient ≥ 0.5.",
    "Compound-treats-Disease": "The Compound is a disease-modifying indication for the Disease (i.e. the Compound therapeutically changes the underlying or downstream biology of the Disease) according to PharmacotherapyDB",
    "Compound-upregulates-Gene": "The Gene is over-expressed in samples exposed to the Compound according to a consensus signature from LINCS L1000",
    "Disease-associates-Gene": "The Gene is associated with the Gene according to GWAS Catalog, DISEASES, DisGeNET, or DOAF",
    "Disease-downregulates-Gene": "The Gene is under-expressed in Disease samples according to a STARGEO meta-analysis",
    "Disease-localizes-Anatomy": "The Disease affects or is related to the Anatomy as inferred by co-occurrence in MEDLINE abstracts",
    "Disease-presents-Symptom": "The Disease presents the Anatomy as inferred by co-occurrence in MEDLINE abstracts",
    "Disease-resembles-Disease": "Two Diseases are similar as inferred by co-occurrence in MEDLINE abstracts",
    "Disease-upregulates-Gene": "The Gene is over-expressed in Disease samples according to a STARGEO meta-analysis",
    "Gene-covaries-Gene": "Two genes have similar evolutionary histories in mammals, according to Evolutionary Rate Covariation ≥ 0.7 (Priedigkeit et al, 2015)",
    "Gene-interacts-Gene": "The genes produce physically-interacting proteins in humans according to the Human Reference Protein Interactome Mapping Project, the Incomplete Interactome, or other PPI databases previously used by Hetio",
    "Gene-participates-Biological Process": "The Gene's product participates in the Biological Process (or its subterms) according to Gene Ontology Annotations",
    "Gene-participates-Cellular Component": "The Gene's product participates in the Cellular Component (or its subterms) according to Gene Ontology Annotations",
    "Gene-participates-Molecular Function": "The Gene's product participates in the Molecular Function (or its subterms) according to Gene Ontology Annotations",
    "Gene-participates-Pathway": "The Gene participates in the Pathway, according WikiPathways, Reactome, or Pathway Interaction Database",
    "Gene-regulates-Gene": "Knockdown or over-expression of the source Gene significantly dysregulated the target Gene according to a consensus signature from LINCS L1000 genetic interference screens",
    "Pharmacologic Class-includes-Compound": "The Compound belongs to the Pharmacologic Class according to DrugCentral"
  }

# %%
## construct node dictionary

Anatomy_nodes = {}
Biological_Process_nodes = {}
Cellular_Component_nodes = {}
Compound_nodes = {}
Disease_nodes = {}
Gene_nodes = {}
Molecular_Function_nodes = {}
Pathway_nodes = {}
Pharmacologic_Class_nodes = {}
Side_Effect_nodes = {}
Symptom_nodes = {}

id_set = set()

## add nodes
for nd in tqdm(raw_data['nodes']):
    node_type = '_'.join(nd['kind'].split(' '))
    idd = str(nd['identifier'])
    assert idd not in id_set
    id_set.add(idd)

    exec(f"{node_type}_nodes[idd]=dict(features=dict(), neighbors=defaultdict(list))")
    exec(f"{node_type}_nodes[idd]['features']['name']=nd['name']")
    for k in nd['data']:
        if k not in ['source', 'license']:
            exec(f"{node_type}_nodes[idd]['features'][k]=nd['data'][k]")
    exec(f"{node_type}_nodes[idd]['features']['node_type']=node_type")

print(len(Anatomy_nodes), len(Biological_Process_nodes), len(Cellular_Component_nodes), len(Compound_nodes), len(Disease_nodes), len(Gene_nodes), len(Molecular_Function_nodes), len(Pathway_nodes), len(Pharmacologic_Class_nodes), len(Side_Effect_nodes), len(Symptom_nodes))
print(len(Anatomy_nodes)+len(Biological_Process_nodes)+len(Cellular_Component_nodes)+len(Compound_nodes)+len(Disease_nodes)+len(Gene_nodes)+len(Molecular_Function_nodes)+len(Pathway_nodes)+len(Pharmacologic_Class_nodes)+len(Side_Effect_nodes)+len(Symptom_nodes))

## add edges
for eg in tqdm(raw_data['edges']):
    source_node_type = '_'.join(eg['source_id'][0].split(' '))
    source_idd = str(eg['source_id'][1])
    target_node_type = '_'.join(eg['target_id'][0].split(' '))
    target_idd = str(eg['target_id'][1])
    edge_type = eg['source_id'][0] + '-' + eg['kind'] + '-' + eg['target_id'][0]

    assert edge_type in metaedges, edge_type

    #exec(f"{source_node_type}_nodes[source_idd]['neighbors'][edge_type]=[target_idd] if edge_type not in {source_node_type}_nodes[source_idd]['neighbors'] else {source_node_type}_nodes[source_idd]['neighbors'][edge_type].append(target_idd)")
    exec(f"{source_node_type}_nodes[source_idd]['neighbors'][edge_type].append(target_idd)")
    if eg['direction'] == 'both':
        exec(f"{target_node_type}_nodes[target_idd]['neighbors'][edge_type].append(source_idd)")
# Out:
#   0%|          | 0/47031 [00:00<?, ?it/s]
# 100%|██████████| 47031/47031 [00:03<00:00, 14182.50it/s]
# 402 11381 1391 1552 137 20945 2884 1822 345 5734 438
# 47031
# 100%|██████████| 2250197/2250197 [01:05<00:00, 34294.42it/s]

# %%
## save graph

json.dump({
    'Anatomy_nodes': Anatomy_nodes,
    'Biological_Process_nodes': Biological_Process_nodes,
    'Cellular_Component_nodes': Cellular_Component_nodes,
    'Compound_nodes': Compound_nodes,
    'Disease_nodes': Disease_nodes,
    'Gene_nodes': Gene_nodes,
    'Molecular_Function_nodes': Molecular_Function_nodes,
    'Pathway_nodes': Pathway_nodes,
    'Pharmacologic_Class_nodes': Pharmacologic_Class_nodes,
    'Side_Effect_nodes': Side_Effect_nodes,
    'Symptom_nodes': Symptom_nodes
}, open(os.path.join(save_dir, 'graph.json'),"w"), indent=4)
